# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
# Import the random module.
import random

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
from citipy import citipy
cities=[]
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 753

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url ="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11b4d4389addda1a6d896998d5ceb171

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        #print("city_weather=%s" % city_weather)
        lat = city_weather['coord']['lat']
        #print("lat:%s" % lat)
        lon = city_weather['coord']['lon']
        #print("lon:%s" % lon)
        max_temp = city_weather['main']['temp_max']
        #print("max_temp=%s" % max_temp)
        humidity = city_weather['main']['humidity']
        #print("humidity=%s" % humidity)
        cloudiness = city_weather['clouds']['all']
        #print("cloudiness=%s" % cloudiness)
        wind = city_weather['wind']['speed']
        #print("wind=%s" % wind)
        country = city_weather['sys']['country']
        #print("country=%s" % country)
        weather_description = city_weather['weather'][0]['description']
        #print("weather_description=%s" % weather_description)     
            
        # Append the city information into the city_data list
        row = [city, country, lat, lon, max_temp, humidity, cloudiness, wind, weather_description]
        city_data.append(row)
    
    # If an error is experienced, skip the city
    except Exception as e:
        print("City not found. Skipping..., error:%s" % e)
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | solnechnyy
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping..., error:'coord'
# Processing Record 4 of Set 1 | langenthal
# Processing Record 5 of Set 1 | oga
# Processing Record 6 of Set 1 | shingu
# Processing Record 7 of Set 1 | souillac
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | port arthur
# Processing Record 10 of Set 1 | langholm
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | amderma
# City not found. Skipping..., error:'coord'
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | marsh harbour
# Processing Record 15 of Set 1 | kungurtug
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | port hardy
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | tiksi
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | kerema
# Processing Record 22 of Set 1 | srednekolymsk
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | simao
# Processing Record 26 of Set 1 | chokurdakh
# Processing Record 27 of Set 1 | beidao
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | santa maria da vitoria
# Processing Record 30 of Set 1 | harper
# Processing Record 31 of Set 1 | luanda
# Processing Record 32 of Set 1 | pangody
# Processing Record 33 of Set 1 | saint-joseph
# Processing Record 34 of Set 1 | san cristobal
# Processing Record 35 of Set 1 | kendari
# Processing Record 36 of Set 1 | bilma
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | saryshagan
# City not found. Skipping..., error:'coord'
# Processing Record 39 of Set 1 | airai
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | magadan
# Processing Record 42 of Set 1 | sumenep
# Processing Record 43 of Set 1 | cabra
# Processing Record 44 of Set 1 | atar
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | raymond
# Processing Record 47 of Set 1 | mehamn
# Processing Record 48 of Set 1 | goderich
# Processing Record 49 of Set 1 | high level
# Processing Record 50 of Set 1 | masindi
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | saskylakh
# Processing Record 3 of Set 2 | evensk
# Processing Record 4 of Set 2 | coquimbo
# Processing Record 5 of Set 2 | daru
# Processing Record 6 of Set 2 | kisanga
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | lorengau
# Processing Record 10 of Set 2 | emerald
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | baker city
# Processing Record 14 of Set 2 | bethel
# Processing Record 15 of Set 2 | karratha
# Processing Record 16 of Set 2 | buala
# Processing Record 17 of Set 2 | samfya
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | namibe
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | kawalu
# Processing Record 22 of Set 2 | pathein
# Processing Record 23 of Set 2 | belushya guba
# City not found. Skipping..., error:'coord'
# Processing Record 24 of Set 2 | yellowknife
# Processing Record 25 of Set 2 | ponta do sol
# Processing Record 26 of Set 2 | berdigestyakh
# Processing Record 27 of Set 2 | tasiilaq
# Processing Record 28 of Set 2 | meulaboh
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | katsuura
# Processing Record 31 of Set 2 | bandarbeyla
# Processing Record 32 of Set 2 | darhan
# Processing Record 33 of Set 2 | lebu
# Processing Record 34 of Set 2 | primorsko-akhtarsk
# Processing Record 35 of Set 2 | east london
# Processing Record 36 of Set 2 | puerto ayora
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping..., error:'coord'
# Processing Record 38 of Set 2 | constitucion
# Processing Record 39 of Set 2 | portland
# Processing Record 40 of Set 2 | xique-xique
# Processing Record 41 of Set 2 | karwar
# Processing Record 42 of Set 2 | kurilsk
# Processing Record 43 of Set 2 | kahului
# Processing Record 44 of Set 2 | yingshang
# City not found. Skipping..., error:'coord'
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | nueva guinea
# Processing Record 47 of Set 2 | hami
# Processing Record 48 of Set 2 | coaldale
# Processing Record 49 of Set 2 | san patricio
# Processing Record 50 of Set 2 | porbandar
# Processing Record 1 of Set 3 | port alfred
# Processing Record 2 of Set 3 | flinders
# Processing Record 3 of Set 3 | suicheng
# Processing Record 4 of Set 3 | hobart
# Processing Record 5 of Set 3 | tubruq
# City not found. Skipping..., error:'coord'
# Processing Record 6 of Set 3 | baracoa
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | mantua
# Processing Record 9 of Set 3 | sur
# Processing Record 10 of Set 3 | vaini
# Processing Record 11 of Set 3 | katete
# Processing Record 12 of Set 3 | cairns
# Processing Record 13 of Set 3 | nizhneyansk
# City not found. Skipping..., error:'coord'
# Processing Record 14 of Set 3 | isangel
# Processing Record 15 of Set 3 | eha amufu
# Processing Record 16 of Set 3 | codrington
# Processing Record 17 of Set 3 | sitka
# Processing Record 18 of Set 3 | naspur
# Processing Record 19 of Set 3 | inta
# Processing Record 20 of Set 3 | pimentel
# Processing Record 21 of Set 3 | nizwa
# Processing Record 22 of Set 3 | longyearbyen
# Processing Record 23 of Set 3 | barra do bugres
# Processing Record 24 of Set 3 | kapaa
# Processing Record 25 of Set 3 | khonuu
# City not found. Skipping..., error:'coord'
# Processing Record 26 of Set 3 | bubaque
# Processing Record 27 of Set 3 | cayenne
# Processing Record 28 of Set 3 | teguldet
# Processing Record 29 of Set 3 | leningradskiy
# Processing Record 30 of Set 3 | halifax
# Processing Record 31 of Set 3 | arshan
# Processing Record 32 of Set 3 | iqaluit
# Processing Record 33 of Set 3 | padang
# Processing Record 34 of Set 3 | san ignacio
# Processing Record 35 of Set 3 | aranos
# Processing Record 36 of Set 3 | geraldton
# Processing Record 37 of Set 3 | mahebourg
# Processing Record 38 of Set 3 | monte alegre
# Processing Record 39 of Set 3 | inyonga
# Processing Record 40 of Set 3 | qaanaaq
# Processing Record 41 of Set 3 | mount gambier
# Processing Record 42 of Set 3 | bembereke
# Processing Record 43 of Set 3 | margate
# Processing Record 44 of Set 3 | aksu
# Processing Record 45 of Set 3 | aykhal
# Processing Record 46 of Set 3 | wuwei
# Processing Record 47 of Set 3 | deputatskiy
# Processing Record 48 of Set 3 | comodoro rivadavia
# Processing Record 49 of Set 3 | arraial do cabo
# Processing Record 50 of Set 3 | butaritari
# Processing Record 1 of Set 4 | the valley
# Processing Record 2 of Set 4 | taranagar
# Processing Record 3 of Set 4 | chicama
# Processing Record 4 of Set 4 | kruisfontein
# Processing Record 5 of Set 4 | kodiak
# Processing Record 6 of Set 4 | norman wells
# Processing Record 7 of Set 4 | kargasok
# Processing Record 8 of Set 4 | vangazi
# Processing Record 9 of Set 4 | flin flon
# Processing Record 10 of Set 4 | palaiokhora
# City not found. Skipping..., error:'coord'
# Processing Record 11 of Set 4 | pyatnitskoye
# Processing Record 12 of Set 4 | lagoa
# Processing Record 13 of Set 4 | kampene
# Processing Record 14 of Set 4 | klaksvik
# Processing Record 15 of Set 4 | vila
# Processing Record 16 of Set 4 | kalmunai
# Processing Record 17 of Set 4 | rundu
# Processing Record 18 of Set 4 | bridlington
# Processing Record 19 of Set 4 | santiago
# Processing Record 20 of Set 4 | vaitupu
# City not found. Skipping..., error:'coord'
# Processing Record 21 of Set 4 | miri
# Processing Record 22 of Set 4 | praia da vitoria
# Processing Record 23 of Set 4 | shache
# Processing Record 24 of Set 4 | mar del plata
# Processing Record 25 of Set 4 | boende
# Processing Record 26 of Set 4 | porterville
# Processing Record 27 of Set 4 | marsa matruh
# Processing Record 28 of Set 4 | haibowan
# City not found. Skipping..., error:'coord'
# Processing Record 29 of Set 4 | roald
# Processing Record 30 of Set 4 | pevek
# Processing Record 31 of Set 4 | castro
# Processing Record 32 of Set 4 | saint-georges
# Processing Record 33 of Set 4 | nanortalik
# Processing Record 34 of Set 4 | west bay
# Processing Record 35 of Set 4 | tokmak
# Processing Record 36 of Set 4 | kousseri
# Processing Record 37 of Set 4 | ayni
# Processing Record 38 of Set 4 | banda aceh
# Processing Record 39 of Set 4 | hasaki
# Processing Record 40 of Set 4 | ostrovnoy
# Processing Record 41 of Set 4 | pecs
# Processing Record 42 of Set 4 | provideniya
# Processing Record 43 of Set 4 | guerrero negro
# Processing Record 44 of Set 4 | rosetta
# Processing Record 45 of Set 4 | dunedin
# Processing Record 46 of Set 4 | upernavik
# Processing Record 47 of Set 4 | glens falls
# Processing Record 48 of Set 4 | redwater
# Processing Record 49 of Set 4 | safwah
# City not found. Skipping..., error:'coord'
# Processing Record 50 of Set 4 | bondo
# Processing Record 1 of Set 5 | ketchikan
# Processing Record 2 of Set 5 | ugoofaaru
# Processing Record 3 of Set 5 | sentyabrskiy
# City not found. Skipping..., error:'coord'
# Processing Record 4 of Set 5 | clonakilty
# Processing Record 5 of Set 5 | bani
# Processing Record 6 of Set 5 | agadez
# Processing Record 7 of Set 5 | vao
# Processing Record 8 of Set 5 | russell
# Processing Record 9 of Set 5 | jamestown
# Processing Record 10 of Set 5 | avera
# Processing Record 11 of Set 5 | cedar city
# Processing Record 12 of Set 5 | bengkulu
# Processing Record 13 of Set 5 | mount isa
# Processing Record 14 of Set 5 | tsihombe
# City not found. Skipping..., error:'coord'
# Processing Record 15 of Set 5 | vila velha
# Processing Record 16 of Set 5 | byron bay
# Processing Record 17 of Set 5 | zhezkazgan
# Processing Record 18 of Set 5 | tamiahua
# Processing Record 19 of Set 5 | yulara
# Processing Record 20 of Set 5 | talaya
# Processing Record 21 of Set 5 | wawa
# Processing Record 22 of Set 5 | salalah
# Processing Record 23 of Set 5 | karaul
# City not found. Skipping..., error:'coord'
# Processing Record 24 of Set 5 | talcahuano
# Processing Record 25 of Set 5 | pangnirtung
# Processing Record 26 of Set 5 | sabang
# Processing Record 27 of Set 5 | sakakah
# Processing Record 28 of Set 5 | tanout
# Processing Record 29 of Set 5 | luderitz
# Processing Record 30 of Set 5 | grand river south east
# City not found. Skipping..., error:'coord'
# Processing Record 31 of Set 5 | baykalsk
# Processing Record 32 of Set 5 | vila franca do campo
# Processing Record 33 of Set 5 | alta floresta
# Processing Record 34 of Set 5 | bacuit
# City not found. Skipping..., error:'coord'
# Processing Record 35 of Set 5 | wanning
# Processing Record 36 of Set 5 | rio gallegos
# Processing Record 37 of Set 5 | fortuna
# Processing Record 38 of Set 5 | severnyy
# Processing Record 39 of Set 5 | vitim
# Processing Record 40 of Set 5 | basco
# Processing Record 41 of Set 5 | makakilo city
# Processing Record 42 of Set 5 | viedma
# Processing Record 43 of Set 5 | thompson
# Processing Record 44 of Set 5 | victoria
# Processing Record 45 of Set 5 | newport
# Processing Record 46 of Set 5 | barentsburg
# City not found. Skipping..., error:'coord'
# Processing Record 47 of Set 5 | mendi
# Processing Record 48 of Set 5 | praia
# Processing Record 49 of Set 5 | yucaipa
# Processing Record 50 of Set 5 | quatre cocos
# Processing Record 1 of Set 6 | chuy
# Processing Record 2 of Set 6 | valdemarpils
# Processing Record 3 of Set 6 | sidi ali
# Processing Record 4 of Set 6 | kristinehamn
# Processing Record 5 of Set 6 | godec
# City not found. Skipping..., error:'coord'
# Processing Record 6 of Set 6 | elizabeth city
# Processing Record 7 of Set 6 | vardo
# Processing Record 8 of Set 6 | dingle
# Processing Record 9 of Set 6 | baia de arama
# Processing Record 10 of Set 6 | te anau
# Processing Record 11 of Set 6 | dapaong
# Processing Record 12 of Set 6 | vostok
# Processing Record 13 of Set 6 | krasnoborsk
# Processing Record 14 of Set 6 | moree
# Processing Record 15 of Set 6 | los llanos de aridane
# Processing Record 16 of Set 6 | edmundston
# Processing Record 17 of Set 6 | cerrito
# Processing Record 18 of Set 6 | koutiala
# Processing Record 19 of Set 6 | faya
# Processing Record 20 of Set 6 | nelson bay
# Processing Record 21 of Set 6 | yining
# Processing Record 22 of Set 6 | dibulla
# Processing Record 23 of Set 6 | saint george
# Processing Record 24 of Set 6 | sandviken
# Processing Record 25 of Set 6 | bathsheba
# Processing Record 26 of Set 6 | omsukchan
# Processing Record 27 of Set 6 | hamilton
# Processing Record 28 of Set 6 | bowen
# Processing Record 29 of Set 6 | esperance
# Processing Record 30 of Set 6 | biltine
# Processing Record 31 of Set 6 | severo-kurilsk
# Processing Record 32 of Set 6 | cherskiy
# Processing Record 33 of Set 6 | ocos
# Processing Record 34 of Set 6 | bindura
# Processing Record 35 of Set 6 | shirokiy
# Processing Record 36 of Set 6 | thilogne
# City not found. Skipping..., error:'coord'
# Processing Record 37 of Set 6 | san ramon
# Processing Record 38 of Set 6 | kaminskiy
# Processing Record 39 of Set 6 | kavieng
# Processing Record 40 of Set 6 | ahuimanu
# Processing Record 41 of Set 6 | taoudenni
# Processing Record 42 of Set 6 | pangai
# Processing Record 43 of Set 6 | chagda
# City not found. Skipping..., error:'coord'
# Processing Record 44 of Set 6 | verkhnevilyuysk
# Processing Record 45 of Set 6 | bodden town
# Processing Record 46 of Set 6 | kontagora
# Processing Record 47 of Set 6 | port maria
# Processing Record 48 of Set 6 | marsaxlokk
# Processing Record 49 of Set 6 | kuching
# Processing Record 50 of Set 6 | mys shmidta
# City not found. Skipping..., error:'coord'
# Processing Record 1 of Set 7 | zharkent
# Processing Record 2 of Set 7 | hihifo
# City not found. Skipping..., error:'coord'
# Processing Record 3 of Set 7 | natal
# Processing Record 4 of Set 7 | ilulissat
# Processing Record 5 of Set 7 | salinopolis
# Processing Record 6 of Set 7 | cabo san lucas
# Processing Record 7 of Set 7 | marrakesh
# Processing Record 8 of Set 7 | villa carlos paz
# Processing Record 9 of Set 7 | san vicente
# Processing Record 10 of Set 7 | pangoa
# Processing Record 11 of Set 7 | bac lieu
# Processing Record 12 of Set 7 | chulman
# Processing Record 13 of Set 7 | torrington
# Processing Record 14 of Set 7 | isla mujeres
# Processing Record 15 of Set 7 | bonito
# Processing Record 16 of Set 7 | marcona
# City not found. Skipping..., error:'coord'
# Processing Record 17 of Set 7 | villa guerrero
# Processing Record 18 of Set 7 | batagay-alyta
# Processing Record 19 of Set 7 | yarada
# Processing Record 20 of Set 7 | port-cartier
# Processing Record 21 of Set 7 | buraydah
# Processing Record 22 of Set 7 | nemuro
# Processing Record 23 of Set 7 | ixtapa
# Processing Record 24 of Set 7 | grand gaube
# Processing Record 25 of Set 7 | half moon bay
# Processing Record 26 of Set 7 | esqueda
# Processing Record 27 of Set 7 | havre-saint-pierre
# Processing Record 28 of Set 7 | talnakh
# Processing Record 29 of Set 7 | bucerias
# Processing Record 30 of Set 7 | port elizabeth
# Processing Record 31 of Set 7 | necochea
# Processing Record 32 of Set 7 | fukue
# Processing Record 33 of Set 7 | chapaevsk
# Processing Record 34 of Set 7 | bokoro
# Processing Record 35 of Set 7 | sao filipe
# Processing Record 36 of Set 7 | uvinza
# Processing Record 37 of Set 7 | itacare
# Processing Record 38 of Set 7 | yar-sale
# Processing Record 39 of Set 7 | burica
# City not found. Skipping..., error:'coord'
# Processing Record 40 of Set 7 | tadine
# Processing Record 41 of Set 7 | lyubeshiv
# City not found. Skipping..., error:'coord'
# Processing Record 42 of Set 7 | saleaula
# City not found. Skipping..., error:'coord'
# Processing Record 43 of Set 7 | luis correia
# Processing Record 44 of Set 7 | honiara
# Processing Record 45 of Set 7 | pingliang
# Processing Record 46 of Set 7 | ust-kamchatsk
# City not found. Skipping..., error:'coord'
# Processing Record 47 of Set 7 | faanui
# Processing Record 48 of Set 7 | nome
# Processing Record 49 of Set 7 | awbari
# Processing Record 50 of Set 7 | cockburn town
# Processing Record 1 of Set 8 | gamba
# Processing Record 2 of Set 8 | san jose
# Processing Record 3 of Set 8 | tuatapere
# Processing Record 4 of Set 8 | tabialan
# City not found. Skipping..., error:'coord'
# Processing Record 5 of Set 8 | cap malheureux
# Processing Record 6 of Set 8 | dong hoi
# Processing Record 7 of Set 8 | warqla
# City not found. Skipping..., error:'coord'
# Processing Record 8 of Set 8 | tumannyy
# City not found. Skipping..., error:'coord'
# Processing Record 9 of Set 8 | ribeira grande
# Processing Record 10 of Set 8 | tual
# Processing Record 11 of Set 8 | nizhneudinsk
# Processing Record 12 of Set 8 | laguna
# Processing Record 13 of Set 8 | alta
# Processing Record 14 of Set 8 | sao gabriel da cachoeira
# Processing Record 15 of Set 8 | murgab
# Processing Record 16 of Set 8 | azare
# Processing Record 17 of Set 8 | payakumbuh
# Processing Record 18 of Set 8 | atbasar
# Processing Record 19 of Set 8 | pacific grove
# Processing Record 20 of Set 8 | bartica
# Processing Record 21 of Set 8 | irbeyskoye
# Processing Record 22 of Set 8 | cumaribo
# City not found. Skipping..., error:'coord'
# Processing Record 23 of Set 8 | la orilla
# Processing Record 24 of Set 8 | biak
# Processing Record 25 of Set 8 | namatanai
# Processing Record 26 of Set 8 | chapais
# Processing Record 27 of Set 8 | logrono
# Processing Record 28 of Set 8 | shimoda
# Processing Record 29 of Set 8 | abha
# Processing Record 30 of Set 8 | coihaique
# Processing Record 31 of Set 8 | bafoulabe
# Processing Record 32 of Set 8 | broome
# Processing Record 33 of Set 8 | nantucket
# Processing Record 34 of Set 8 | bambous virieux
# Processing Record 35 of Set 8 | moyale
# Processing Record 36 of Set 8 | suhbaatar
# Processing Record 37 of Set 8 | abnub
# Processing Record 38 of Set 8 | teguise
# Processing Record 39 of Set 8 | sturgeon falls
# Processing Record 40 of Set 8 | homestead
# Processing Record 41 of Set 8 | itaqui
# Processing Record 42 of Set 8 | belyy yar
# Processing Record 43 of Set 8 | prieska
# Processing Record 44 of Set 8 | haines junction
# Processing Record 45 of Set 8 | palabuhanratu
# City not found. Skipping..., error:'coord'
# Processing Record 46 of Set 8 | luz
# Processing Record 47 of Set 8 | hay river
# Processing Record 48 of Set 8 | yatou
# Processing Record 49 of Set 8 | lufkin
# Processing Record 50 of Set 8 | nisia floresta
# Processing Record 1 of Set 9 | traverse city
# Processing Record 2 of Set 9 | richards bay
# Processing Record 3 of Set 9 | eydhafushi
# Processing Record 4 of Set 9 | pisco
# Processing Record 5 of Set 9 | kachiry
# Processing Record 6 of Set 9 | guadalupe y calvo
# Processing Record 7 of Set 9 | stoyba
# City not found. Skipping..., error:'coord'
# Processing Record 8 of Set 9 | yartsevo
# Processing Record 9 of Set 9 | bajo baudo
# City not found. Skipping..., error:'coord'
# Processing Record 10 of Set 9 | san carlos de bariloche
# Processing Record 11 of Set 9 | tilichiki
# Processing Record 12 of Set 9 | bereda
# Processing Record 13 of Set 9 | antalaha
# Processing Record 14 of Set 9 | asau
# Processing Record 15 of Set 9 | uarini
# Processing Record 16 of Set 9 | darnah
# Processing Record 17 of Set 9 | mago
# Processing Record 18 of Set 9 | barahona
# Processing Record 19 of Set 9 | peterhead
# Processing Record 20 of Set 9 | birao
# Processing Record 21 of Set 9 | vizinga
# Processing Record 22 of Set 9 | knysna
# Processing Record 23 of Set 9 | tobermory
# Processing Record 24 of Set 9 | waseca
# Processing Record 25 of Set 9 | uige
# Processing Record 26 of Set 9 | port lincoln
# Processing Record 27 of Set 9 | cururupu
# Processing Record 28 of Set 9 | waingapu
# Processing Record 29 of Set 9 | narsaq
# Processing Record 30 of Set 9 | beisfjord
# Processing Record 31 of Set 9 | ciudad valles
# Processing Record 32 of Set 9 | lerwick
# Processing Record 33 of Set 9 | valparaiso
# Processing Record 34 of Set 9 | penzance
# Processing Record 35 of Set 9 | sechura
# Processing Record 36 of Set 9 | maracacume
# Processing Record 37 of Set 9 | novyy starodub
# Processing Record 38 of Set 9 | port augusta
# Processing Record 39 of Set 9 | roanne
# Processing Record 40 of Set 9 | kaitangata
# Processing Record 41 of Set 9 | sakaiminato
# Processing Record 42 of Set 9 | kijang
# Processing Record 43 of Set 9 | alice
# Processing Record 44 of Set 9 | satis
# Processing Record 45 of Set 9 | indramayu
# Processing Record 46 of Set 9 | paradwip
# City not found. Skipping..., error:'coord'
# Processing Record 47 of Set 9 | sorland
# Processing Record 48 of Set 9 | ucluelet
# Processing Record 49 of Set 9 | sorvag
# City not found. Skipping..., error:'coord'
# Processing Record 50 of Set 9 | kaputa
# Processing Record 1 of Set 10 | sioux lookout
# Processing Record 2 of Set 10 | taonan
# Processing Record 3 of Set 10 | ryotsu
# Processing Record 4 of Set 10 | vilyuysk
# Processing Record 5 of Set 10 | lisakovsk
# Processing Record 6 of Set 10 | palma
# Processing Record 7 of Set 10 | bayan
# Processing Record 8 of Set 10 | nouakchott
# Processing Record 9 of Set 10 | vaitape
# Processing Record 10 of Set 10 | borogontsy
# Processing Record 11 of Set 10 | lasa
# Processing Record 12 of Set 10 | tura
# Processing Record 13 of Set 10 | jasper
# Processing Record 14 of Set 10 | kuusamo
# Processing Record 15 of Set 10 | pontes e lacerda
# Processing Record 16 of Set 10 | strezhevoy
# Processing Record 17 of Set 10 | lata
# Processing Record 18 of Set 10 | kaihua
# Processing Record 19 of Set 10 | tezu
# Processing Record 20 of Set 10 | barraute
# Processing Record 21 of Set 10 | terra santa
# Processing Record 22 of Set 10 | santa vitoria do palmar
# Processing Record 23 of Set 10 | barreirinhas
# Processing Record 24 of Set 10 | najran
# Processing Record 25 of Set 10 | kumluca
# Processing Record 26 of Set 10 | pochutla
# Processing Record 27 of Set 10 | lompoc
# Processing Record 28 of Set 10 | pandan
# Processing Record 29 of Set 10 | turtas
# Processing Record 30 of Set 10 | zeerust
# Processing Record 31 of Set 10 | barabai
# Processing Record 32 of Set 10 | wanaka
# Processing Record 33 of Set 10 | san rafael
# Processing Record 34 of Set 10 | olafsvik
# Processing Record 35 of Set 10 | caohai
# Processing Record 36 of Set 10 | attawapiskat
# City not found. Skipping..., error:'coord'
# Processing Record 37 of Set 10 | fairbanks
# Processing Record 38 of Set 10 | korla
# Processing Record 39 of Set 10 | taltal
# Processing Record 40 of Set 10 | alice springs
# Processing Record 41 of Set 10 | banepa
# Processing Record 42 of Set 10 | sungaipenuh
# Processing Record 43 of Set 10 | hofn
# Processing Record 44 of Set 10 | sahrak
# City not found. Skipping..., error:'coord'
# Processing Record 45 of Set 10 | haliyal
# Processing Record 46 of Set 10 | virden
# Processing Record 47 of Set 10 | miraflores
# Processing Record 48 of Set 10 | ternate
# Processing Record 49 of Set 10 | saldanha
# Processing Record 50 of Set 10 | thanh hoa
# Processing Record 1 of Set 11 | gushikawa
# Processing Record 2 of Set 11 | ouallam
# Processing Record 3 of Set 11 | hotton
# Processing Record 4 of Set 11 | avanigadda
# Processing Record 5 of Set 11 | coahuayana
# Processing Record 6 of Set 11 | grand forks
# Processing Record 7 of Set 11 | muravlenko
# Processing Record 8 of Set 11 | bari
# Processing Record 9 of Set 11 | bijie
# Processing Record 10 of Set 11 | itupiranga
# Processing Record 11 of Set 11 | sayyan
# Processing Record 12 of Set 11 | santa cruz del sur
# Processing Record 13 of Set 11 | grand-santi
# Processing Record 14 of Set 11 | lonavale
# Processing Record 15 of Set 11 | barawe
# City not found. Skipping..., error:'coord'
# Processing Record 16 of Set 11 | tanggu
# Processing Record 17 of Set 11 | denpasar
# Processing Record 18 of Set 11 | cidreira
# Processing Record 19 of Set 11 | ipanema
# Processing Record 20 of Set 11 | lavrentiya
# Processing Record 21 of Set 11 | gravdal
# Processing Record 22 of Set 11 | mikkeli
# Processing Record 23 of Set 11 | ambunti
# Processing Record 24 of Set 11 | touros
# Processing Record 25 of Set 11 | ahipara
# Processing Record 26 of Set 11 | alotau
# City not found. Skipping..., error:'coord'
# Processing Record 27 of Set 11 | chapleau
# Processing Record 28 of Set 11 | rawah
# Processing Record 29 of Set 11 | joshimath
# Processing Record 30 of Set 11 | rangkasbitung
# Processing Record 31 of Set 11 | tofield
# Processing Record 32 of Set 11 | samusu
# City not found. Skipping..., error:'coord'
# Processing Record 33 of Set 11 | waddan
# Processing Record 34 of Set 11 | acapulco
# Processing Record 35 of Set 11 | whitehorse
# Processing Record 36 of Set 11 | westport
# Processing Record 37 of Set 11 | calvinia
# Processing Record 38 of Set 11 | qaqortoq
# Processing Record 39 of Set 11 | nuuk
# Processing Record 40 of Set 11 | kuvshinovo
# Processing Record 41 of Set 11 | ypsonas
# Processing Record 42 of Set 11 | normandin
# Processing Record 43 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 11 | ginir
# Processing Record 45 of Set 11 | burns lake
# Processing Record 46 of Set 11 | alofi
# Processing Record 47 of Set 11 | utiroa
# City not found. Skipping..., error:'coord'
# Processing Record 48 of Set 11 | santander de quilichao
# Processing Record 49 of Set 11 | muisne
# Processing Record 50 of Set 11 | kiruna
# Processing Record 1 of Set 12 | kattivakkam
# Processing Record 2 of Set 12 | angoram
# Processing Record 3 of Set 12 | chipinge
# Processing Record 4 of Set 12 | nabire
# Processing Record 5 of Set 12 | aljezur
# Processing Record 6 of Set 12 | teeli
# Processing Record 7 of Set 12 | phan rang
# City not found. Skipping..., error:'coord'
# Processing Record 8 of Set 12 | sudzha
# Processing Record 9 of Set 12 | kuala terengganu
# Processing Record 10 of Set 12 | moose factory
# Processing Record 11 of Set 12 | peoria
# Processing Record 12 of Set 12 | teo
# Processing Record 13 of Set 12 | lishan
# Processing Record 14 of Set 12 | locri
# Processing Record 15 of Set 12 | yamada
# Processing Record 16 of Set 12 | labuan
# Processing Record 17 of Set 12 | popondetta
# Processing Record 18 of Set 12 | poum
# Processing Record 19 of Set 12 | la reforma
# Processing Record 20 of Set 12 | acajutla
# Processing Record 21 of Set 12 | tateyama
# Processing Record 22 of Set 12 | port-gentil
# Processing Record 23 of Set 12 | aswan
# Processing Record 24 of Set 12 | aasiaat
# Processing Record 25 of Set 12 | saint-ambroise
# Processing Record 26 of Set 12 | nevel
# Processing Record 27 of Set 12 | dzhusaly
# City not found. Skipping..., error:'coord'
# Processing Record 28 of Set 12 | danville
# Processing Record 29 of Set 12 | giyani
# Processing Record 30 of Set 12 | barcelos
# Processing Record 31 of Set 12 | andros town
# Processing Record 32 of Set 12 | aktash
# Processing Record 33 of Set 12 | arlit
# Processing Record 34 of Set 12 | phun phin
# City not found. Skipping..., error:'coord'
# Processing Record 35 of Set 12 | ivanava
# Processing Record 36 of Set 12 | ancud
# Processing Record 37 of Set 12 | souris
# Processing Record 38 of Set 12 | divnoye
# Processing Record 39 of Set 12 | vikhorevka
# Processing Record 40 of Set 12 | kuche
# City not found. Skipping..., error:'coord'
# Processing Record 41 of Set 12 | mayya
# Processing Record 42 of Set 12 | turbat
# Processing Record 43 of Set 12 | moanda
# Processing Record 44 of Set 12 | egvekinot
# Processing Record 45 of Set 12 | camacha
# Processing Record 46 of Set 12 | xiashi
# Processing Record 47 of Set 12 | carballo
# Processing Record 48 of Set 12 | yomitan
# City not found. Skipping..., error:'coord'
# Processing Record 49 of Set 12 | kavaratti
# Processing Record 50 of Set 12 | tessalit
# Processing Record 1 of Set 13 | raudeberg
# Processing Record 2 of Set 13 | shadrinsk
# Processing Record 3 of Set 13 | umzimvubu
# City not found. Skipping..., error:'coord'
# Processing Record 4 of Set 13 | adrar
# Processing Record 5 of Set 13 | prince rupert
# Processing Record 6 of Set 13 | maghama
# City not found. Skipping..., error:'coord'
# Processing Record 7 of Set 13 | rustenburg
# Processing Record 8 of Set 13 | matagami
# Processing Record 9 of Set 13 | kerman
# Processing Record 10 of Set 13 | erenhot
# Processing Record 11 of Set 13 | taybad
# Processing Record 12 of Set 13 | huilong
# Processing Record 13 of Set 13 | kamina
# Processing Record 14 of Set 13 | nongstoin
# Processing Record 15 of Set 13 | porgera
# Processing Record 16 of Set 13 | madarounfa
# Processing Record 17 of Set 13 | belmonte
# Processing Record 18 of Set 13 | bria
# Processing Record 19 of Set 13 | donskoye
# Processing Record 20 of Set 13 | tabas
# Processing Record 21 of Set 13 | college
# Processing Record 22 of Set 13 | isla vista
# Processing Record 23 of Set 13 | berlevag
# Processing Record 24 of Set 13 | matara
# Processing Record 25 of Set 13 | naze
# Processing Record 26 of Set 13 | soyo
# Processing Record 27 of Set 13 | trzcianka
# Processing Record 28 of Set 13 | bushehr
# Processing Record 29 of Set 13 | okha
# Processing Record 30 of Set 13 | cabedelo
# Processing Record 31 of Set 13 | ouadda
# Processing Record 32 of Set 13 | ola
# Processing Record 33 of Set 13 | nenjiang
# Processing Record 34 of Set 13 | shimanovsk
# Processing Record 35 of Set 13 | paamiut
# Processing Record 36 of Set 13 | baloda
# Processing Record 37 of Set 13 | gunnedah
# Processing Record 38 of Set 13 | husavik
# Processing Record 39 of Set 13 | kasongo-lunda
# Processing Record 40 of Set 13 | lucapa
# Processing Record 41 of Set 13 | udachnyy
# Processing Record 42 of Set 13 | porto nacional
# Processing Record 43 of Set 13 | lac du bonnet
# Processing Record 44 of Set 13 | beloha
# Processing Record 45 of Set 13 | impfondo
# Processing Record 46 of Set 13 | henties bay
# Processing Record 47 of Set 13 | mahon
# Processing Record 48 of Set 13 | cueramaro
# Processing Record 49 of Set 13 | parkes
# Processing Record 50 of Set 13 | batagay
# Processing Record 1 of Set 14 | ndele
# Processing Record 2 of Set 14 | bequimao
# Processing Record 3 of Set 14 | namtsy
# Processing Record 4 of Set 14 | lalsk
# Processing Record 5 of Set 14 | bonavista
# Processing Record 6 of Set 14 | coffs harbour
# Processing Record 7 of Set 14 | pella
# Processing Record 8 of Set 14 | kaduqli
# Processing Record 9 of Set 14 | tabulbah
# City not found. Skipping..., error:'coord'
# Processing Record 10 of Set 14 | laela
# Processing Record 11 of Set 14 | baykit
# Processing Record 12 of Set 14 | torbay
# Processing Record 13 of Set 14 | siniscola
# Processing Record 14 of Set 14 | ahmadpur east
# Processing Record 15 of Set 14 | hagenow
# Processing Record 16 of Set 14 | moron
# Processing Record 17 of Set 14 | kisangani
# Processing Record 18 of Set 14 | karachi
# Processing Record 19 of Set 14 | hengshui
# Processing Record 20 of Set 14 | quelimane
# Processing Record 21 of Set 14 | san luis
# Processing Record 22 of Set 14 | nosy varika
# Processing Record 23 of Set 14 | itarema
# Processing Record 24 of Set 14 | bargal
# City not found. Skipping..., error:'coord'
# Processing Record 25 of Set 14 | freeport
# Processing Record 26 of Set 14 | tarakan
# Processing Record 27 of Set 14 | fort nelson
# Processing Record 28 of Set 14 | champerico
# Processing Record 29 of Set 14 | sergeyevka
# Processing Record 30 of Set 14 | kilindoni
# Processing Record 31 of Set 14 | dhidhdhoo
# Processing Record 32 of Set 14 | katherine
# Processing Record 33 of Set 14 | southbridge
# Processing Record 34 of Set 14 | sosnovo-ozerskoye
# Processing Record 35 of Set 14 | abu samrah
# Processing Record 36 of Set 14 | winnemucca
# Processing Record 37 of Set 14 | den helder
# Processing Record 38 of Set 14 | stonewall
# Processing Record 39 of Set 14 | witu
# Processing Record 40 of Set 14 | mahibadhoo
# Processing Record 41 of Set 14 | lillesand
# Processing Record 42 of Set 14 | saveh
# Processing Record 43 of Set 14 | jiaozuo
# Processing Record 44 of Set 14 | tucuma
# Processing Record 45 of Set 14 | hokitika
# Processing Record 46 of Set 14 | merauke
# Processing Record 47 of Set 14 | safford
# Processing Record 48 of Set 14 | anadyr
# Processing Record 49 of Set 14 | mayo
# Processing Record 50 of Set 14 | slave lake
# Processing Record 1 of Set 15 | ayagoz
# Processing Record 2 of Set 15 | buchanan
# Processing Record 3 of Set 15 | kurtamysh
# Processing Record 4 of Set 15 | mogok
# Processing Record 5 of Set 15 | ntcheu
# Processing Record 6 of Set 15 | bolshoy uluy
# City not found. Skipping..., error:'coord'
# Processing Record 7 of Set 15 | taveta
# Processing Record 8 of Set 15 | port hawkesbury
# Processing Record 9 of Set 15 | burnie
# Processing Record 10 of Set 15 | hanzhong
# Processing Record 11 of Set 15 | myitkyina
# Processing Record 12 of Set 15 | williams lake
# Processing Record 13 of Set 15 | vallenar
# Processing Record 14 of Set 15 | tucurui
# Processing Record 15 of Set 15 | gorele
# Processing Record 16 of Set 15 | susehri
# Processing Record 17 of Set 15 | indiana
# Processing Record 18 of Set 15 | aklavik
# Processing Record 19 of Set 15 | raduzhnyy
# Processing Record 20 of Set 15 | canmore
# Processing Record 21 of Set 15 | sibolga
# Processing Record 22 of Set 15 | shangzhi
# Processing Record 23 of Set 15 | salgueiro
# Processing Record 24 of Set 15 | gualaquiza
# Processing Record 25 of Set 15 | marivan
# Processing Record 26 of Set 15 | ovruch
# Processing Record 27 of Set 15 | la ronge
# Processing Record 28 of Set 15 | luchegorsk
# Processing Record 29 of Set 15 | majene
# Processing Record 30 of Set 15 | zhigansk
# Processing Record 31 of Set 15 | mergui
# City not found. Skipping..., error:'coord'
# Processing Record 32 of Set 15 | sola
# Processing Record 33 of Set 15 | meadow lake
# Processing Record 34 of Set 15 | calbuco
# Processing Record 35 of Set 15 | huntsville
# Processing Record 36 of Set 15 | manaus
# Processing Record 37 of Set 15 | presidencia roque saenz pena
# Processing Record 38 of Set 15 | verdun
# Processing Record 39 of Set 15 | safaqis
# City not found. Skipping..., error:'coord'
# Processing Record 40 of Set 15 | tomatlan
# Processing Record 41 of Set 15 | cervo
# Processing Record 42 of Set 15 | khani
# Processing Record 43 of Set 15 | acari
# Processing Record 44 of Set 15 | pacasmayo
# Processing Record 45 of Set 15 | dubbo
# Processing Record 46 of Set 15 | mecca
# Processing Record 47 of Set 15 | andevoranto
# City not found. Skipping..., error:'coord'
# Processing Record 48 of Set 15 | temaraia
# City not found. Skipping..., error:'coord'
# Processing Record 49 of Set 15 | eldikan
# City not found. Skipping..., error:'coord'
# Processing Record 50 of Set 15 | noumea
# Processing Record 1 of Set 16 | mizan teferi
# Processing Record 2 of Set 16 | betafo
# Processing Record 3 of Set 16 | siderno
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
print(len(city_data))
# Out:
# 694

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              0   1        2         3      4   5    6      7                8
# 0      rikitea  PF -23.1203 -134.9692  71.80  73   99  12.64  overcast clouds
# 1   solnechnyy  RU  50.7214  136.6319  21.34  87  100   1.86  overcast clouds
# 2   langenthal  CH  47.2153    7.7961  48.79  93   99   7.56       light rain
# 3          oga  IT  46.4631   10.3470  38.80  78   99   7.65  overcast clouds
# 4       shingu  JP  33.7333  135.9833  53.24  78    1   4.68        clear sky
# 5     souillac  MU -20.5167   57.5167  80.98  47   20   9.22       few clouds
# 6     hermanus  ZA -34.4187   19.2345  69.80  54  100   9.06  overcast clouds
# 7  port arthur  CN  38.8000  121.2667  52.02  75  100  11.23  overcast clouds
# 8     langholm  GB  55.1510   -2.9989  47.01  90  100   9.55  overcast clouds
# 9      mataura  NZ -46.1927  168.8643  52.34  98   68   3.85    moderate rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# %%
#Create a list to reorder the column names as follows:
#"City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order =["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
df = city_data_df[new_column_order]

# Display sample data
print(df)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         rikitea      PF -23.1203 -134.9692     71.80        73          99
# 1      solnechnyy      RU  50.7214  136.6319     21.34        87         100
# 2      langenthal      CH  47.2153    7.7961     48.79        93          99
# 3             oga      IT  46.4631   10.3470     38.80        78          99
# 4          shingu      JP  33.7333  135.9833     53.24        78           1
# ..            ...     ...      ...       ...       ...       ...         ...
# 689         mecca      SA  21.4267   39.8261     88.12        36           2
# 690        noumea      NC -22.2763  166.4572     71.58        79          92
# 691  mizan teferi      ET   6.9833   35.5833     76.14        54           6
# 692        betafo      MG -19.8333   46.8500     77.32        50          20
# 693       siderno      IT  38.2779   16.3020     70.99        61          11
#
#      Wind Speed Current Description
# 0         12.64     overcast clouds
# 1          1.86     overcast clouds
# 2          7.56          light rain
# 3          7.65     overcast clouds
# 4          4.68           clear sky
# ..          ...                 ...
# 689        6.38           clear sky
# 690        6.17     overcast clouds
# 691        3.24          light rain
# 692        4.25          light rain
# 693        5.86          few clouds
#
# [694 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
outfile = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
df.to_csv(outfile)
